# %% [markdown]
# #Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ##Line Plot
#
#  A line graph, also known as a line chart or a line plot, is commonly drawn to show information that changes over time. You can plot it by using several points linked by straight lines. It comprises two axes called the “x-axis” and the “y-axis”.

# %% [markdown]
# Task#1
#
# a. Import matplotlib
#
# b. Create a list of x and y variables
#
# c. Create a line chart

# %%
import matplotlib.pyplot as plt

x = [2,3,4,5,6,9]

y = [5,6,8,9,10,11]

plt.plot(x,y)

# %% [markdown]
# Task#2
#
# a. Create a list using the range() function starting from year 1950 to 2100.
#
#
# b. Create a list using the range() function starting from year 1950 to 2101 with the intervals of 10.
#
# c. Create a neg_list using the range() function starting from -1 to -100.

# %%
year = list(range(1950,2101))

year_interval = list(range(1950,2101, 10))

neg_list = list(range(1950,2101, 10))

# %% [markdown]
# Task#3
#
# use this pop list:
#
# pop=[2.53, 2.57, 2.62, 2.67, 2.71, 2.76, 2.81, 2.86, 2.92, 2.97, 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47, 3.54, 3.62, 3.69, 3.77, 3.84, 3.92, 4.0, 4.07, 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69, 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41, 5.49, 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05, 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67, 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 7.24, 7.32, 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94, 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49, 8.56, 8.62, 8.68, 8.74, 8.8, 8.86, 8.92, 8.98, 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41, 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77, 9.81, 9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06, 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31, 10.33, 10.36, 10.38, 10.41, 10.43, 10.46, 10.48, 10.5, 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66, 10.68, 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79, 10.81, 10.82, 10.83, 10.84, 10.85]
#
#
# Use the list you created for year 1950 to 2101 print() the last item from
# both the year and the pop list (population forecast in billions) to see what
# the predicted population for the year 2100 is.

# %%
pop=[2.53, 2.57, 2.62, 2.67, 2.71, 2.76, 2.81, 2.86, 2.92, 2.97, 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47, 3.54, 3.62, 3.69, 3.77, 3.84, 3.92, 4.0, 4.07, 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69, 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41, 5.49, 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05, 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67, 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 7.24, 7.32, 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94, 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49, 8.56, 8.62, 8.68, 8.74, 8.8, 8.86, 8.92, 8.98, 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41, 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77, 9.81, 9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06, 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31, 10.33, 10.36, 10.38, 10.41, 10.43, 10.46, 10.48, 10.5, 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66, 10.68, 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79, 10.81, 10.82, 10.83, 10.84, 10.85]

# %%
print(year[-1])

print(pop[-1])
# Out:
# 2100
# 10.85

# %% [markdown]
# Task#4
#
#
# Create line plot of world projected population. Year should be mapped on
# the horizontal axis, population on the vertical axis.

# %%
plt.plot(year, pop)

# %% [markdown]
# Task#5
#
#
# Create a line plot using the following data for monthly savings.
#
# ![image.png](data:image/png;base64,...)

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

savings = [209.00, 250.00, 209.00, 297.00, 356.00, 388.00,
           305.00, 397.00, 362.00, 237.00, 282.00, 238.00]

plt.plot(months, savings)

# %% [markdown]
# Task#6
#
# **W O R LD GDP PER CAPITA – TASK BACKGROUND**
#
# *We’ve collected data life_exp which contains the life expectancy for each country and
# gdp_cap, which contains the GDP per capita (i.e. per person) for each country
# expressed in US Dollars.
# GDP stands for Gross Domestic Product. It basically represents the size of the
# economy of a country. Divide this by the population and we get the GDP per capita*
#
#
# a. Print the last item from both the list (GDP per Capita) gdp_cap, and the list (Life
# Expectancy) life_exp.
#
# b. Build a line chart, with gdp_cap and life_exp.
#
# read data ('https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/gapminder.csv')

# %% [markdown]
# plt.plot(x,y)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/gapminder.csv')

print(df[['life_exp','gdp_cap']].iloc[-1])
# Out:
# life_exp     43.487000
# gdp_cap     469.709298
# Name: 141, dtype: float64

# %%
plt.plot(df[['gdp_cap', 'life_exp']])

# %% [markdown]
# Task#7
#
# a. Create a list of variables x and y
#
# b. Create a scatter plot

# %%
import matplotlib.pyplot as plt

x = [2,3,4,5,6,9]

y = [5,6,8,9,10,11]

plt.scatter(x,y)

# %% [markdown]
# **Scatter Plot syntax**
#
# plt.scatter(x,y, size, color, marker)

# %%
plt.scatter(x,y, s = 2, color = 'blue', marker = '*')

# %% [markdown]
# Task#8
#
# a. Create a scatter plot with gdp_cap and life_exp.

# %%
plt.scatter(df['gdp_cap'], df['life_exp'])

# %% [markdown]
# Task#9
#
# ![image.png](data:image/png;base64,...)
#
# a. Using the savings data create a scatter plot?

# %%
month = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
Savings=[209.00,250.00,209.00,297.00,356.00,388.00,305.00,397.00,362.00,237.00,282.00,238.00]

plt.scatter(month,Savings)

# %% [markdown]
# ##Histogram
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within discrete bins.

# %% [markdown]
# Task#10
#
# a. Generate a list of numbers (10-200)
#
# b. Create a histogram
#
# c. Create a histogram with bins

# %%
numbers = [0.18, -0.35, 0.97, -1.22, 0.56, -0.89, 0.14, 1.09, -0.67, 0.42, -0.11, -1.58, 0.03, 0.75, 1.26, -0.24, -0.92, 1.47, 0.63, -0.18]
plt.hist(numbers, bins = 5)
# Out:
# (array([2., 3., 7., 4., 4.]),
#  array([-1.58, -0.97, -0.36,  0.25,  0.86,  1.47]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# Task#11
#
# Use plt.hist() to create a histogram of the values in life_exp and display the
# histogram.

# %%
plt.hist(df['life_exp'])
# Out:
# (array([ 8.,  7., 10., 10., 10.,  8.,  5., 33., 23., 28.]),
#  array([39.613, 43.912, 48.211, 52.51 , 56.809, 61.108, 65.407, 69.706,
#         74.005, 78.304, 82.603]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Task#12
#
# a.  plt.hist() to create a histogram of the values in life_exp and display the
# histogram.
#
# b. Build a histogram of life_exp, with 5 bins. Can you tell which bin contains the
# most observations?
#
# c. Build another histogram of life_exp, this time with 20 bins. Is this better?

# %%
plt.hist(df['life_exp'])

# %%
plt.hist(df['life_exp'], bins = 5)
# Out:
# (array([15., 20., 18., 38., 51.]),
#  array([39.613, 48.211, 56.809, 65.407, 74.005, 82.603]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['life_exp'], bins = 20)
# Out:
# (array([ 1.,  7.,  2.,  5.,  4.,  6.,  5.,  5.,  4.,  6.,  3.,  5.,  5.,
#          0., 12., 21., 13., 10., 17., 11.]),
#  array([39.613 , 41.7625, 43.912 , 46.0615, 48.211 , 50.3605, 52.51  ,
#         54.6595, 56.809 , 58.9585, 61.108 , 63.2575, 65.407 , 67.5565,
#         69.706 , 71.8555, 74.005 , 76.1545, 78.304 , 80.4535, 82.603 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# #Bar Graphs
#
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle

# %% [markdown]
# Task#13
#
# a. Load Car Details dataset
#
# b. Print its metadata

# %% [markdown]
# What is the structure of the car dataset, and what are the data types of its columns?

# %% [markdown]
# What are the first 10 records in the car dataset?

# %% [markdown]
# *    What is the average selling price of cars for each fuel type, sorted in
# *   How does the average selling price vary across different fuel types, when displayed in ascending order?
#
# *    What is the average selling price of cars for each fuel type, sorted in
# descending order?
# *   How does the average selling price vary across different fuel types, when displayed in descending order
# ascending order?

# %%
df = pd.read_csv('/content/CAR DETAILS.csv')

df.head(10)
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner
# 0          60000      70000  Petrol  Individual       Manual   First Owner
# 1         135000      50000  Petrol  Individual       Manual   First Owner
# 2         600000     100000  Diesel  Individual       Manual   First Owner
# 3         250000      46000  Petrol  Individual       Manual   First Owner
# 4         450000     141000  Diesel  Individual       Manual  Second Owner
# 5         140000     125000  Petrol  Individual       Manual   First Owner
# 6         550000      25000  Petrol  Individual       Manual   First Owner
# 7         240000      60000  Petrol  Individual       Manual  Second Owner
# 8         850000      25000  Petrol  Individual       Manual   First Owner
# 9         365000      78000     CNG  Individual       Manual   First Owner

# %%
df.columns
# Out:
# Index(['age', 'gender', 'miles', 'debt', 'income', 'sales'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     963 non-null    int64
#  1   gender  963 non-null    int64
#  2   miles   963 non-null    int64
#  3   debt    963 non-null    int64
#  4   income  963 non-null    int64
#  5   sales   963 non-null    int64
# dtypes: int64(6)
# memory usage: 45.3 KB

# %%
average_selling_price_by_fuel = df.groupby('fuel')['selling_price'].mean().sort_values()

average_selling_price_by_fuel
# Out:
# fuel
# LPG         167826.043478
# CNG         277174.925000
# Electric    310000.000000
# Petrol      344840.137541
# Diesel      669094.252206
# Name: selling_price, dtype: float64

# %%
average_selling_price_by_fuel_asc = df.groupby('fuel')['selling_price'].mean().sort_values(ascending=True)
print("Average selling price by fuel type (ascending):\n", average_selling_price_by_fuel_asc)
# Out:
# Average selling price by fuel type (ascending):
#  fuel
# LPG         167826.043478
# CNG         277174.925000
# Electric    310000.000000
# Petrol      344840.137541
# Diesel      669094.252206
# Name: selling_price, dtype: float64

# %%
average_selling_price_by_fuel_desc = df.groupby('fuel')['selling_price'].mean().sort_values(ascending=False)
print("\nAverage selling price by fuel type (descending):\n", average_selling_price_by_fuel_desc)

# %% [markdown]
# #Seaborn
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# Let's discuss some plots that allow us to visualize the data set. These plots are:
#
# * Scatter Plot
# * Line Plot
# * Bar Graph
# * Histogram
# * Heatmap

# %%
import seaborn as sn

# %% [markdown]
# ### Selling Price by Fuel Type

# %% [markdown]
# ### Selling Price by Fuel Type and Seller Type
# How does the average selling price vary across different fuel types and seller types?
#
#  How does the average selling price vary across different seller types and fuel types?
#
#  How does the average selling price vary across different fuel types and transmission types?

# %% [markdown]
# ### Fuel Type Distribution
# What is the count of cars for each fuel type in the dataset?
#
# ### Bar Plot for Fuel Type Distribution
# How are cars distributed across different fuel types?

# %% [markdown]
# ### Seller Type Distribution
#  What is the count of cars for each seller type in the dataset?
# ###Bar Plot for Seller Type Distribution
#
#  How are cars distributed across different seller types

# %% [markdown]
# ### Transmission Type Distribution

# %% [markdown]
# ### Selling Price Distribution

# %%
# Fitting a logarithmic trend line
coefficients = np.polyfit(np.log(gdp_cap + 1), life_exp, 1)
log_fit = np.poly1d(coefficients)

# Generating points for the trend line
gdp_cap_sorted = np.sort(gdp_cap)
life_exp_fit = log_fit(np.log(gdp_cap_sorted + 1))

# Plotting the trend line
plt.plot(gdp_cap_sorted, life_exp_fit, color='red', label='Logarithmic Fit')
plt.xlabel('GDP per Capita')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy vs GDP per Capita with Logarithmic Fit')
plt.legend()
plt.show()
