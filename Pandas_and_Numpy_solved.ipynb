# %% [markdown]
# #Pandas

# %% [markdown]
# Task# 1
#
# a. Import pandas library
#
# b. Read csv data from "https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/mlbData.csv")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##MLB data

# %%
mlb = pd.read_csv("https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/mlbData.csv")

# %%
mlb.head(5)
# Out:
#    Height  Weight    Age
# 0      74     180  22.99
# 1      74     215  34.69
# 2      72     210  30.78
# 3      72     210  35.43
# 4      73     188  35.71

# %%
mlb.dtypes
# Out:
# Height      int64
# Weight      int64
# Age       float64
# dtype: object

# %%
mlb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  1015 non-null   int64
#  1   Weight  1015 non-null   int64
#  2   Age     1015 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 23.9 KB

# %%
mlb.Height
# Out:
# 0       74
# 1       74
# 2       72
# 3       72
# 4       73
#         ..
# 1010    73
# 1011    74
# 1012    75
# 1013    75
# 1014    73
# Name: Height, Length: 1015, dtype: int64

# %% [markdown]
# Task# 2
#
# Convert the units of height and weight to metric (meters and kilograms respectively).

# %%
mlb['Height'] = mlb['Height'] * 0.0254

mlb['Weight'] = mlb['Weight'] * 0.453592

# %% [markdown]
# Task# 2
#
# a. Read csv data from a local folder.
#
# b. Read excel data from a local folder.

# %%
df = pd.read_csv('/content/cars.csv')

# %%
df = pd.read_excel('/content/ks-projects-201612.xlsx')

# %% [markdown]
# ##Advertising Data

# %% [markdown]
# df = pd.read_csv(r"C:/Users/zaina/OneDrive/Desktop/Advertising.csv")

# %%
advertising=pd.read_csv('/content/Advertising.csv')
advertising
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# Task# 3
#
# a. Print shape and columns of advertising data.
#
# b. Print all information on advertising data.

# %%
advertising.shape
# Out:
# (200, 5)

# %%
advertising.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# Task# 4
#
# a. Print sales(millionUSD) field only.
#
# b. Create a subset that contains SocialMedia(millionUSD), sales(millionUSD), newspaper(millionUSD) fields.

# %%
print(advertising['Sales'])
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
subset = advertising[['TV', 'Sales', 'Newspaper']]

subset
# Out:
#         TV  Sales  Newspaper
# 0    230.1   22.1       69.2
# 1     44.5   10.4       45.1
# 2     17.2    9.3       69.3
# 3    151.5   18.5       58.5
# 4    180.8   12.9       58.4
# ..     ...    ...        ...
# 195   38.2    7.6       13.8
# 196   94.2    9.7        8.1
# 197  177.0   12.8        6.4
# 198  283.6   25.5       66.2
# 199  232.1   13.4        8.7
#
# [200 rows x 3 columns]

# %% [markdown]
# Task# 5
#
# a. Apply a filter condition to filter out less than 9 million USD sales. Print a boolean index series.
#
# b. Return complete advertising dataframe with this filter condition applied.

# %%
boolean_indexing = advertising['Sales'] < 9

boolean_indexing
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195     True
# 196    False
# 197    False
# 198    False
# 199    False
# Name: Sales, Length: 200, dtype: bool

# %%
updated_advertising = advertising[boolean_indexing]

updated_advertising
# Out:
#      Unnamed: 0    TV  Radio  Newspaper  Sales
# 5             6   8.7   48.9       75.0    7.2
# 8             9   8.6    2.1        1.0    4.8
# 10           11  66.1    5.8       24.2    8.6
# 22           23  13.2   15.9       49.6    5.6
# 44           45  25.1   25.7       43.3    8.5
# 56           57   7.3   28.1       41.4    5.5
# 60           61  53.5    2.0       21.4    8.1
# 72           73  26.8   33.0       19.3    8.8
# 75           76  16.9   43.7       89.4    8.7
# 76           77  27.5    1.6       20.7    6.9
# 78           79   5.4   29.9        9.4    5.3
# 91           92  28.6    1.5       33.0    7.3
# 106         107  25.0   11.0       29.7    7.2
# 107         108  90.4    0.3       23.2    8.7
# 108         109  13.1    0.4       25.6    5.3
# 119         120  19.4   16.0       22.3    6.6
# 121         122  18.8   21.7       50.4    7.0
# 126         127   7.8   38.9       50.6    6.6
# 127         128  80.2    0.0        9.2    8.8
# ...

# %% [markdown]
# Task# 6
#
# a. Read data from CAR DETAILS.csv and load it into a pandas dataframe.
#
# b. Filter out the data to only display cars with fuel type petrol.
#
# c. Filter out the data to only display cars with fuel type petrol and Diesel.

# %%
# prompt: Filter out the data to only display cars with fuel type petrol and Diesel.

# Filter for petrol cars
petrol_cars = df[df['fuel'] == 'Petrol']

# Filter for petrol and diesel cars
petrol_diesel_cars = df[df['fuel'].isin(['Petrol', 'Diesel'])]

petrol_diesel_cars

# %%
car = pd.read_csv('/content/CAR DETAILS.csv')
car
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 6 columns]

# %%
feul_type = car[car['fuel'] == 'Petrol' ]

feul_type
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 5            140000     125000  Petrol  Individual       Manual   First Owner
# 6            550000      25000  Petrol  Individual       Manual   First Owner
# ...             ...        ...     ...         ...          ...           ...
# 4326          65000     150000  Petrol  Individual       Manual   Third Owner
# 4327         190000      60000  Petrol  Individual       Manual  Second Owner
# 4329         160000      60000  Petrol  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
# [2123 rows x 6 columns]

# %%
fuel_diesel = car[car['fuel'].isin(['Petrol', 'Diesel'])]

fuel_diesel
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
# [4276 rows x 6 columns]
